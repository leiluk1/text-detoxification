# %% [markdown]
# # Fine-tuning the T5 model
#
# The checkpoint was used: `t5-base`.
#
# For the whole implementation, check the `src/models/t5` folder.

# %%
# Required installations
# !pip install sacrebleu rouge_score

# %% [markdown]
# ## Cloning the repository

# %%
# !git clone https://github.com/leiluk1/text-detoxification.git
# Out:
# Cloning into 'text-detoxification'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 153 (delta 51), reused 107 (delta 30), pack-reused 23
# Receiving objects: 100% (153/153), 44.14 MiB | 51.84 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# If using a Kaggle
# %cd /kaggle/working/text-detoxification
# Out:
# /kaggle/working/text-detoxification

# %% [markdown]
# ## Making the dataset

# %%
# !python ./src/data/make_dataset.py
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Done successfully! Check data/interim folder.

# %% [markdown]
# ## Training the model

# %%
# !python ./src/models/t5/train.py --batch_size 16 --epochs 10
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Downloading (…)lve/main/config.json: 100%|█| 1.21k/1.21k [00:00<00:00, 8.29MB/s]
# Downloading (…)ve/main/spiece.model: 100%|███| 792k/792k [00:00<00:00, 8.44MB/s]
# Downloading (…)/main/tokenizer.json: 100%|█| 1.39M/1.39M [00:00<00:00, 41.2MB/s]
# Downloading builder script: 7.65kB [00:00, 6.04MB/s]
# Downloading builder script: 5.60kB [00:00, 4.49MB/s]
# Downloading model.safetensors: 100%|██████████| 892M/892M [00:03<00:00, 228MB/s]
# Downloading (…)neration_config.json: 100%|█████| 147/147 [00:00<00:00, 1.00MB/s]
# 100%|███████████████████████████████████████████| 76/76 [00:06<00:00, 11.92ba/s]
# 100%|███████████████████████████████████████████| 19/19 [00:01<00:00, 12.27ba/s]
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 1.9855, 'learning_rate': 1.9578947368421055e-05, 'epoch': 0.21}
# {'loss': 1.7895, 'learning_rate': 1.9157894736842108e-05, 'epoch': 0.42}
# {'loss': 1.7645, 'learning_rate': 1.873684210526316e-05, 'epoch': 0.63}
# {'loss': 1.7104, 'learning_rate': 1.831578947368421e-05, 'epoch': 0.84}
# {'eval_loss': 1.58316969871521, 'eval_bleu': 26.8431, 'eval_rouge1': 0.576, 'eval_rouge2': 0.3601, 'eval_gen_len': 11.6584, 'eval_runtime': 375.285, 'eval_samples_per_second': 50.628, 'eval_steps_per_second': 1.583, 'epoch': 1.0}
# {'loss': 1.6939, 'learning_rate': 1.7894736842105264e-05, 'epoch': 1.05}
# {'loss': 1.661, 'learning_rate': 1.7473684210526317e-05, 'epoch': 1.26}
# {'loss': 1.65, 'learning_rate': 1.705263157894737e-05, 'epoch': 1.47}
# {'loss': 1.6383, 'learning_rate': 1.6631578947368423e-05, 'epoch': 1.68}
# {'loss': 1.6352, 'learning_rate': 1.6210526315789473e-05, 'epoch': 1.89}
# {'eval_loss': 1.536309003829956, 'eval_bleu': 27.6637, 'eval_rouge1': 0.5841, 'eval_rouge2': 0.3712, 'eval_gen_len': 11.6086, 'eval_runtime': 375.3951, 'eval_samples_per_second': 50.613, 'eval_steps_per_second': 1.582, 'epoch': 2.0}
# {'loss': 1.5962, 'learning_rate': 1.578947368421053e-05, 'epoch': 2.11}
# {'loss': 1.5898, 'learning_rate': 1.536842105263158e-05, 'epoch': 2.32}
# {'loss': 1.5895, 'learning_rate': 1.4947368421052632e-05, 'epoch': 2.53}
# {'loss': 1.5794, 'learning_rate': 1.4526315789473687e-05, 'epoch': 2.74}
# {'loss': 1.588, 'learning_rate': 1.4105263157894738e-05, 'epoch': 2.95}
# {'eval_loss': 1.5098899602890015, 'eval_bleu': 28.0732, 'eval_rouge1': 0.5864, 'eval_rouge2': 0.3746, 'eval_gen_len': 11.5959, 'eval_runtime': 375.4792, 'eval_samples_per_second': 50.602, 'eval_steps_per_second': 1.582, 'epoch': 3.0}
# {'loss': 1.5519, 'learning_rate': 1.3684210526315791e-05, 'epoch': 3.16}
# {'loss': 1.5485, 'learning_rate': 1.3263157894736843e-05, 'epoch': 3.37}
# {'loss': 1.5499, 'learning_rate': 1.2842105263157896e-05, 'epoch': 3.58}
# {'loss': 1.5506, 'learning_rate': 1.2421052631578949e-05, 'epoch': 3.79}
# {'loss': 1.5456, 'learning_rate': 1.2e-05, 'epoch': 4.0}
# {'eval_loss': 1.495600938796997, 'eval_bleu': 28.2589, 'eval_rouge1': 0.5893, 'eval_rouge2': 0.3781, 'eval_gen_len': 11.5791, 'eval_runtime': 376.5336, 'eval_samples_per_second': 50.46, 'eval_steps_per_second': 1.578, 'epoch': 4.0}
# {'loss': 1.5146, 'learning_rate': 1.1578947368421053e-05, 'epoch': 4.21}
# {'loss': 1.5129, 'learning_rate': 1.1157894736842105e-05, 'epoch': 4.42}
# {'loss': 1.5221, 'learning_rate': 1.073684210526316e-05, 'epoch': 4.63}
# {'loss': 1.5282, 'learning_rate': 1.0315789473684213e-05, 'epoch': 4.84}
# {'eval_loss': 1.483681559562683, 'eval_bleu': 28.3299, 'eval_rouge1': 0.5901, 'eval_rouge2': 0.3794, 'eval_gen_len': 11.5379, 'eval_runtime': 375.5725, 'eval_samples_per_second': 50.589, 'eval_steps_per_second': 1.582, 'epoch': 5.0}
# {'loss': 1.5043, 'learning_rate': 9.894736842105264e-06, 'epoch': 5.05}
# {'loss': 1.4932, 'learning_rate': 9.473684210526315e-06, 'epoch': 5.26}
# {'loss': 1.497, 'learning_rate': 9.05263157894737e-06, 'epoch': 5.47}
# {'loss': 1.4931, 'learning_rate': 8.631578947368422e-06, 'epoch': 5.68}
# {'loss': 1.5016, 'learning_rate': 8.210526315789475e-06, 'epoch': 5.89}
# {'eval_loss': 1.4756686687469482, 'eval_bleu': 28.5929, 'eval_rouge1': 0.592, 'eval_rouge2': 0.3825, 'eval_gen_len': 11.5533, 'eval_runtime': 374.4114, 'eval_samples_per_second': 50.746, 'eval_steps_per_second': 1.586, 'epoch': 6.0}
# {'loss': 1.4845, 'learning_rate': 7.789473684210526e-06, 'epoch': 6.11}
# {'loss': 1.477, 'learning_rate': 7.368421052631579e-06, 'epoch': 6.32}
# {'loss': 1.48, 'learning_rate': 6.947368421052632e-06, 'epoch': 6.53}
# {'loss': 1.4841, 'learning_rate': 6.526315789473685e-06, 'epoch': 6.74}
# {'loss': 1.4692, 'learning_rate': 6.105263157894738e-06, 'epoch': 6.95}
# {'eval_loss': 1.469192385673523, 'eval_bleu': 28.6465, 'eval_rouge1': 0.5921, 'eval_rouge2': 0.3823, 'eval_gen_len': 11.5468, 'eval_runtime': 375.7066, 'eval_samples_per_second': 50.571, 'eval_steps_per_second': 1.581, 'epoch': 7.0}
# {'loss': 1.4665, 'learning_rate': 5.68421052631579e-06, 'epoch': 7.16}
# {'loss': 1.468, 'learning_rate': 5.263157894736842e-06, 'epoch': 7.37}
# {'loss': 1.4705, 'learning_rate': 4.842105263157895e-06, 'epoch': 7.58}
# {'loss': 1.4586, 'learning_rate': 4.4210526315789476e-06, 'epoch': 7.79}
# {'loss': 1.4625, 'learning_rate': 4.000000000000001e-06, 'epoch': 8.0}
# {'eval_loss': 1.4670323133468628, 'eval_bleu': 28.6889, 'eval_rouge1': 0.5929, 'eval_rouge2': 0.3833, 'eval_gen_len': 11.5229, 'eval_runtime': 375.0712, 'eval_samples_per_second': 50.657, 'eval_steps_per_second': 1.584, 'epoch': 8.0}
# {'loss': 1.4556, 'learning_rate': 3.578947368421053e-06, 'epoch': 8.21}
# {'loss': 1.4508, 'learning_rate': 3.157894736842105e-06, 'epoch': 8.42}
# {'loss': 1.461, 'learning_rate': 2.7368421052631583e-06, 'epoch': 8.63}
# {'loss': 1.4607, 'learning_rate': 2.3157894736842105e-06, 'epoch': 8.84}
# {'eval_loss': 1.4648141860961914, 'eval_bleu': 28.7409, 'eval_rouge1': 0.5926, 'eval_rouge2': 0.3831, 'eval_gen_len': 11.5581, 'eval_runtime': 374.651, 'eval_samples_per_second': 50.714, 'eval_steps_per_second': 1.585, 'epoch': 9.0}
# {'loss': 1.4433, 'learning_rate': 1.8947368421052634e-06, 'epoch': 9.05}
# {'loss': 1.4605, 'learning_rate': 1.4736842105263159e-06, 'epoch': 9.26}
# {'loss': 1.4532, 'learning_rate': 1.0526315789473685e-06, 'epoch': 9.47}
# {'loss': 1.444, 'learning_rate': 6.315789473684211e-07, 'epoch': 9.68}
# {'loss': 1.4493, 'learning_rate': 2.105263157894737e-07, 'epoch': 9.89}
# {'eval_loss': 1.4639936685562134, 'eval_bleu': 28.7357, 'eval_rouge1': 0.5931, 'eval_rouge2': 0.3833, 'eval_gen_len': 11.5316, 'eval_runtime': 375.1593, 'eval_samples_per_second': 50.645, 'eval_steps_per_second': 1.583, 'epoch': 10.0}
# {'train_runtime': 17805.3655, 'train_samples_per_second': 42.684, 'train_steps_per_second': 1.334, 'train_loss': 1.5433000886615953, 'epoch': 10.0}
# Training completed. Model saved at models/t5.

# %% [markdown]
# ## Making the predictions on test set
#
# The test set is 5000 text examples from the preprocessed dataset.

# %%
# !python ./src/models/t5/predict.py
# Out:
# Generating predictions...: 100%|██████████| 5000/5000 [1:21:27<00:00,  1.02it/s]
# Done!

# %%
import pandas as pd 

res = pd.read_csv('data/interim/t5_results.csv')
res.head()
# Out:
#                                            reference  \
# 0  He didn't invite me to his wedding, and he's s...
# 1         God damn it, Mary, that's no life for you!
# 2  Cut the crap. You wouldn't even vote for your ...
# 3                "Only the image of evil stupidity?"
# 4          We're here to forget about all that shit.
#
#                                      detox_reference  \
# 0  he didn't invite me to the wedding and he's re...
# 1                  come on Mary, it's not your life!
# 2          wouldn't you vote for your sister-in-law?
# 3                           "just an image of evil?"
# 4                   we're here to forget everything.
#
#                                            t5_result
# 0  he didn't invite me to his wedding, and he's s...
# 1       oh, my God, Mary, that's not a life for you!
# 2     you wouldn't even vote for your sister-in-law?
# 3                          "only the image of evil?"
# 4                   we're here to forget everything.

# %% [markdown]
# ## Inference: some examples

# %%
# !python ./src/models/t5/predict.py --inference "What a stupid joke."
# Out:
# Detoxified: what a bad joke.

# %%
# !python ./src/models/t5/predict.py --inference "Fucking damn joke!"
# Out:
# Detoxified: it's a terrible joke!

# %% [markdown]
# T5 model results:
#
# | Source sentence       | Detoxified sentence    |
# |-----------------------|------------------------|
# | "What a stupid joke." | "what a bad joke."     |
# | "Fucking damn joke!"  | "it's a terrible joke!"|
#
# Based on the these examples, it can be concluded that the model is capable of detoxifying toxic sentences and providing non-toxic alternatives in a natural way.
